# %% [markdown]
# <a href="https://colab.research.google.com/github/stepmoon/Unit_2_Python/blob/main/Mini_Project_Covid19_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1: Environment Set up
import pandas as pd
import numpy as np

# %%
# Task 2: Data Collection
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
df.head(10)
# Out:
#          date       county       state     fips  cases  deaths
# 0  2020-01-21    Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22    Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23    Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24         Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24    Snohomish  Washington  53061.0      1     0.0
# 5  2020-01-25       Orange  California   6059.0      1     0.0
# 6  2020-01-25         Cook    Illinois  17031.0      1     0.0
# 7  2020-01-25    Snohomish  Washington  53061.0      1     0.0
# 8  2020-01-26     Maricopa     Arizona   4013.0      1     0.0
# 9  2020-01-26  Los Angeles  California   6037.0      1     0.0

# %%
# Task 3
state_df = df['state']=='California'
county_df =df['county']=='Orange'
subset_df = df[state_df & county_df]
subset_df
# Out:
#               date  county       state    fips   cases  deaths
# 5       2020-01-25  Orange  California  6059.0       1     0.0
# 10      2020-01-26  Orange  California  6059.0       1     0.0
# 15      2020-01-27  Orange  California  6059.0       1     0.0
# 20      2020-01-28  Orange  California  6059.0       1     0.0
# 25      2020-01-29  Orange  California  6059.0       1     0.0
# ...            ...     ...         ...     ...     ...     ...
# 920732  2021-01-12  Orange  California  6059.0  207318  2148.0
# 923977  2021-01-13  Orange  California  6059.0  211331  2179.0
# 927223  2021-01-14  Orange  California  6059.0  214649  2195.0
# 930468  2021-01-15  Orange  California  6059.0  217925  2277.0
# 933713  2021-01-16  Orange  California  6059.0  221532  2320.0
#
# [358 rows x 6 columns]

# %%
subset_df.groupby(['date'])['cases','deaths'].sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#              cases  deaths
# date
# 2020-01-25       1     0.0
# 2020-01-26       1     0.0
# 2020-01-27       1     0.0
# 2020-01-28       1     0.0
# 2020-01-29       1     0.0
# ...            ...     ...
# 2021-01-12  207318  2148.0
# 2021-01-13  211331  2179.0
# 2021-01-14  214649  2195.0
# 2021-01-15  217925  2277.0
# 2021-01-16  221532  2320.0
#
# [358 rows x 2 columns]

# %%
subset_df.tail(30)
# Out:
#               date  county       state    fips   cases  deaths
# 839601  2020-12-18  Orange  California  6059.0  118721  1734.0
# 842846  2020-12-19  Orange  California  6059.0  122168  1760.0
# 846092  2020-12-20  Orange  California  6059.0  126776  1775.0
# 849337  2020-12-21  Orange  California  6059.0  130530  1777.0
# 852582  2020-12-22  Orange  California  6059.0  132772  1779.0
# 855827  2020-12-23  Orange  California  6059.0  137194  1781.0
# 859072  2020-12-24  Orange  California  6059.0  140699  1782.0
# 862317  2020-12-25  Orange  California  6059.0  141205  1782.0
# 865562  2020-12-26  Orange  California  6059.0  149439  1845.0
# 868807  2020-12-27  Orange  California  6059.0  153527  1846.0
# 872052  2020-12-28  Orange  California  6059.0  157926  1846.0
# 875297  2020-12-29  Orange  California  6059.0  160476  1847.0
# 878542  2020-12-30  Orange  California  6059.0  164990  1874.0
# 881787  2020-12-31  Orange  California  6059.0  166196  1875.0
# ...

# %%
subset_df.shape
# Out:
# (358, 6)

# %%
subset_df.info
# Out:
# <bound method DataFrame.info of               date  county       state    fips   cases  deaths
# 5       2020-01-25  Orange  California  6059.0       1     0.0
# 10      2020-01-26  Orange  California  6059.0       1     0.0
# 15      2020-01-27  Orange  California  6059.0       1     0.0
# 20      2020-01-28  Orange  California  6059.0       1     0.0
# 25      2020-01-29  Orange  California  6059.0       1     0.0
# ...            ...     ...         ...     ...     ...     ...
# 920732  2021-01-12  Orange  California  6059.0  207318  2148.0
# 923977  2021-01-13  Orange  California  6059.0  211331  2179.0
# 927223  2021-01-14  Orange  California  6059.0  214649  2195.0
# 930468  2021-01-15  Orange  California  6059.0  217925  2277.0
# 933713  2021-01-16  Orange  California  6059.0  221532  2320.0
#
# [358 rows x 6 columns]>

# %%
subset_df.isnull()
# Out:
#          date  county  state   fips  cases  deaths
# 5       False   False  False  False  False   False
# 10      False   False  False  False  False   False
# 15      False   False  False  False  False   False
# 20      False   False  False  False  False   False
# 25      False   False  False  False  False   False
# ...       ...     ...    ...    ...    ...     ...
# 920732  False   False  False  False  False   False
# 923977  False   False  False  False  False   False
# 927223  False   False  False  False  False   False
# 930468  False   False  False  False  False   False
# 933713  False   False  False  False  False   False
#
# [358 rows x 6 columns]

# %%
subset_df.isnull().sum()
# Out:
# date      0
# county    0
# state     0
# fips      0
# cases     0
# deaths    0
# dtype: int64

# %%
subset_df.boxplot(column=['cases','deaths'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
newyork_df = df[df['state']=='New York']
newyork_df.tail(30)
# Out:
#               date         county     state     fips   cases   deaths
# 935371  2021-01-16  New York City  New York      NaN  524231  25970.0
# 935372  2021-01-16        Niagara  New York  36063.0   11664    235.0
# 935373  2021-01-16         Oneida  New York  36065.0   16342    335.0
# 935374  2021-01-16       Onondaga  New York  36067.0   26954    520.0
# 935375  2021-01-16        Ontario  New York  36069.0    4592     79.0
# 935376  2021-01-16         Orange  New York  36071.0   28183    564.0
# 935377  2021-01-16        Orleans  New York  36073.0    1882     68.0
# 935378  2021-01-16         Oswego  New York  36075.0    4762     62.0
# 935379  2021-01-16         Otsego  New York  36077.0    1600     21.0
# 935380  2021-01-16         Putnam  New York  36079.0    6294     72.0
# 935381  2021-01-16     Rensselaer  New York  36083.0    6596    101.0
# 935382  2021-01-16       Rockland  New York  36087.0   31346    618.0
# ...

# %%
import seaborn as sns
# %matplotlib inline
newyork_df.head()
# Out:
#            date         county     state     fips  cases  deaths
# 416  2020-03-01  New York City  New York      NaN      1     0.0
# 448  2020-03-02  New York City  New York      NaN      1     0.0
# 482  2020-03-03  New York City  New York      NaN      2     0.0
# 518  2020-03-04  New York City  New York      NaN      2     0.0
# 519  2020-03-04    Westchester  New York  36119.0      9     0.0

# %%
# Confirmed cases _New York 
sns.jointplot(x='date',y='cases',data=newyork_df)

# %%
# Confirmed cases_ California
state_df=df[df['state']=='California']
sns.jointplot(x='date',y='cases',data=state_df)
